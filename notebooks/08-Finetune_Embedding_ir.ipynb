# %% [markdown]
# <a href="https://colab.research.google.com/github/isamdr86/towards-ai/blob/main/notebooks/08-Finetune_Embedding_ir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Packages and Setup Variables

# %%
# !pip install -q llama-index==0.10.65 llama-index-finetuning llama-index-embeddings-adapter openai==1.37.0 tiktoken==0.7.0 chromadb==0.5.5 llama-index-vector-stores-chroma==0.1.10 cohere==5.6.2 llama-index-llms-gemini==0.1.11 html2text llama-index-llms-openai llama-index-embeddings-huggingface llama-index-embeddings-openai llama-index-llms-azure-openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.0/337.0 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.3/584.3 kB 27.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 63.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 67.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.1/679.1 kB 32.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 62.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 44.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 84.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 69.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.9/198.9 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 77.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.7/410.7 kB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 23.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.3/261.3 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.2/113.2 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 78.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 kB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.4 MB/s eta 0:00:00
#   Building wheel for html2text (setup.py) ... done
#   Building wheel for pypika (pyproject.toml) ... done

# %%
# %%capture
# !pip install openai==1.55.3 httpx==0.27.2 tiktoken==0.7.0 --force-reinstall

# %%
import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get('openai_api_key')

# %% [markdown]
# # Download the Dataset

# %%
from huggingface_hub import hf_hub_download
file_path = hf_hub_download(repo_id="jaiganesan/ai_tutor_knowledge", filename="ai_tutor_knowledge.jsonl",repo_type="dataset",local_dir="/content")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ai_tutor_knowledge.jsonl:   0%|          | 0.00/6.96M [00:00<?, ?B/s]

# %%
import json
with open(file_path, "r") as file:
    ai_tutor_knowledge = [json.loads(line) for line in file]

len(ai_tutor_knowledge)
# Out:
# 762

# %% [markdown]
# ## LlamaIndex Document

# %%
ai_tutor_knowledge[0]
# Out:
# {'tokens': 768,
#  'doc_id': 'd72b4670-84f0-54a3-b259-7eb7f218674e',
#  'name': 'BERT HuggingFace Model Deployment using Kubernetes [ Github Repo]  03/07/2024',
#  'url': 'https://towardsai.net/p/machine-learning/bert-huggingface-model-deployment-using-kubernetes-github-repo-03-07-2024',
#  'source': 'tai_blog',
#  'content': 'Github Repo : https://github.com/vaibhawkhemka/ML-Umbrella/tree/main/MLops/Model_Deployment/Bert_Kubernetes_deployment   Model development is useless if you dont deploy it to production  which comes with a lot of issues of scalability and portability.   I have deployed a basic BERT model from the huggingface transformer on Kubernetes with the help of docker  which will give a feel of how to deploy and manage pods on production.   Model Serving and Deployment:ML Pipeline:Workflow:   Model server (using FastAPI  uvicorn) for BERT uncased model    Containerize model and inference scripts to create a docker image    Kubernetes deployment for these model servers (for scalability)  Testing   Components:Model serverUsed BERT uncased model from hugging face for prediction of next word [MASK]. Inference is done using transformer-cli which uses fastapi and uvicorn to serve the model endpoints   Server streaming:   Testing: (fastapi docs)   http://localhost:8888/docs/   { output: [ { score: 0.21721847355365753  token: 2204  token_str: good  sequence: today is a good day }  { score: 0.16623663902282715  token: 2047  token_str: new  sequence: today is a new day }  { score: 0.07342924177646637  token: 2307  token_str: great  sequence: today is a great day }  { score: 0.0656224861741066  token: 2502  token_str: big  sequence: today is a big day }  { score: 0.03518620505928993  token: 3376  token_str: beautiful  sequence: today is a beautiful day } ]   ContainerizationCreated a docker image from huggingface GPU base image and pushed to dockerhub after testing.   Testing on docker container:   You can directly pull the image vaibhaw06/bert-kubernetes:latest   K8s deploymentUsed minikube and kubectl commands to create a single pod container for serving the model by configuring deployment and service config   deployment.yaml   apiVersion: apps/v1 kind: Deployment metadata: name: bert-deployment labels: app: bertapp spec: replicas: 1 selector: matchLabels: app: bertapp template: metadata: labels: app: bertapp spec: containers: - name: bertapp image: vaibhaw06/bert-kubernetes ports: - containerPort: 8080 --- apiVersion: v1 kind: Service metadata: name: bert-service spec: type: NodePort selector: app: bertapp ports: - protocol: TCP port: 8080 targetPort: 8080 nodePort: 30100Setting up minikube and running pods using kubectl and deployment.yaml   minikube start kubectl apply -f deployment.yamlFinal Testing:kubectl get allIt took around 15 mins to pull and create container pods.   kubectl image listkubectl get svcminikube service bert-serviceAfter running the last command minikube service bert-service  you can verify the resulting deployment on the web endpoint.   Find the GitHub Link: https://github.com/vaibhawkhemka/ML-Umbrella/tree/main/MLops/Model_Deployment/Bert_Kubernetes_deployment   If you have any questions  ping me on my LinkedIn: https://www.linkedin.com/in/vaibhaw-khemka-a92156176/   Follow ML Umbrella for more such detailed  actionable projects.   Future Extension:Scaling with pod replicas and load balancer -   Self-healing'}

# %%
from typing import List
from llama_index.core import Document

def create_docs_from_list(data_list: List[dict]) -> List[Document]:
    documents = []
    for data in data_list:
        documents.append(
            Document(
                doc_id=data["doc_id"],
                text=data["content"],
                metadata={  # type: ignore
                    "url": data["url"],
                    "title": data["name"],
                    "tokens": data["tokens"],
                    "source": data["source"],
                },
                excluded_llm_metadata_keys=[
                    "title",
                    "tokens",
                    "source",
                ],
                excluded_embed_metadata_keys=[
                    "url",
                    "tokens",
                    "source",
                ],
            )
        )
    return documents

doc = create_docs_from_list(ai_tutor_knowledge)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /usr/local/lib/python3.10/dist-
# [nltk_data]     packages/llama_index/core/_static/nltk_cache...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %% [markdown]
# ### Splitting Dataset

# %%
import random

random.shuffle(doc)
split_index = int(len(doc) * 0.9)

# TRAIN_DOCs and VALIDATION_DOCs
TRAIN_DOCs = doc[:split_index]
VALIDATION_DOCs = doc[split_index:]

# %% [markdown]
# # Chunking

# %%
from llama_index.core.node_parser import SimpleNodeParser
from llama_index.core.schema import Document

# Now use the parser
parser = SimpleNodeParser.from_defaults(chunk_size=768, chunk_overlap=64)
TRAIN_NODEs = parser.get_nodes_from_documents(TRAIN_DOCs)
VALIDATION_NODEs = parser.get_nodes_from_documents(VALIDATION_DOCs)

print(len(TRAIN_NODEs), len(VALIDATION_NODEs))
# Out:
# 2895 216

# %%
# Use a subset of the dataset if testing.

# Test with a few sample, processing dataset fully can be costly depanding on the size.
# NOTE: Checkpoints are provided in the lesson, so no need to run the code on full dataset.

testing =False

if testing:
    TRAIN_NODEs = TRAIN_NODEs[0:10]
    VALIDATION_NODEs = VALIDATION_NODEs[0:5]

# %% [markdown]
# # Generate Question

# %% [markdown]
# We use a Large Language Model (LLM) to produce questions for each chunk of the dataset. Then we can use these data to train the model to develop embeddings that more accurately represent the types of questions users may ask.

# %%
# Use this block of code if you don't want to generate the questions for the dataset. (Avoid API call charges!)
# Uncomment the following code, and keep in mind to comment all the contents in the next coding block.


# from llama_index.finetuning import generate_qa_embedding_pairs
# from llama_index.llms.openai import OpenAI

# llm = OpenAI(model="gpt-4o-mini", temperature=1, max_tokens=512)

# # Generate questions for each chunk.

# TRAIN_DATASET = generate_qa_embedding_pairs(TRAIN_NODEs, llm=llm, output_path="./train_dataset.json")

# VALIDATION_DATASET = generate_qa_embedding_pairs(VALIDATION_NODEs, llm=llm, output_path="./val_dataset.json")

# %%
from huggingface_hub import snapshot_download
snapshot_download(repo_id="jaiganesan/Embedding-model-fine-tuning-dataset", repo_type="dataset",local_dir="/content/")


from llama_index.finetuning import EmbeddingQAFinetuneDataset

# Load the pre-generated questions json files.
TRAIN_DATASET = EmbeddingQAFinetuneDataset.from_json("./train_dataset.json")
VALIDATION_DATASET = EmbeddingQAFinetuneDataset.from_json("./val_dataset.json")
# Out:
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# train_dataset.json:   0%|          | 0.00/8.23M [00:00<?, ?B/s]
# val_dataset.json:   0%|          | 0.00/789k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/2.42k [00:00<?, ?B/s]

# %% [markdown]
# # Load an Embedding Model

# %%
from llama_index.core.embeddings import resolve_embed_model

# Load an existing embedding model with a linear layer adopter on top.
base_embed_model = resolve_embed_model("local:BAAI/bge-small-en-v1.5")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# . BGE We chose the model because of its lightweight architecture, which makes it suitable for applications with limited computational resources. Also, the performance of smaller models tends to improve more noticeably with fine-tuning compared to larger models.

# %% [markdown]
# A linear adapter is just a linear transformation that transforms query embeddings while keeping document embeddings unchanged.

# %%
from llama_index.finetuning import EmbeddingAdapterFinetuneEngine
import torch

# Finetune the adapter
finetune_engine = EmbeddingAdapterFinetuneEngine(
    TRAIN_DATASET,
    base_embed_model,
    model_output_path="model_output_test",
    epochs=2,
    verbose=True,
    bias=True,
)

# %%
# Initiate the Finetuning process
finetune_engine.finetune()
# Out:
# > Prepared optimizer, scheduler, and loss model.
# Epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/545 [00:00<?, ?it/s]
# > [Epoch 0] Current loss: 1.5546023845672607
# > [Epoch 0] Current loss: 1.5433043241500854
# > [Epoch 0] Current loss: 1.3001140356063843
# > [Epoch 0] Current loss: 1.209113359451294
# > [Epoch 0] Current loss: 1.0383665561676025
# > [Epoch 0] Current loss: 1.0853663682937622
# > [Epoch 0] Current loss: 1.6050153970718384
# > [Epoch 0] Current loss: 1.3934540748596191
# > [Epoch 0] Current loss: 1.6227833032608032
# > [Epoch 0] Current loss: 1.8313658237457275
# > [Epoch 0] Current loss: 2.351806163787842
# > [Epoch 0] Current loss: 2.3631062507629395
# > [Epoch 0] Current loss: 2.266368865966797
# > [Epoch 0] Current loss: 1.8658138513565063
# > [Epoch 0] Current loss: 2.3685429096221924
# > [Epoch 0] Current loss: 2.3456649780273438
# > [Epoch 0] Current loss: 2.4202945232391357
# > [Epoch 0] Current loss: 2.3720555305480957
# > [Epoch 0] Current loss: 2.292235851287842
# > [Epoch 0] Current loss: 2.35850191116333
# > [Epoch 0] Current loss: 2.317695379257202
# > [Epoch 0] Current loss: 2.334578275680542
# > [Epoch 0] Current loss: 1.9019620418548584
# > [Epoch 0] Current loss: 2.3839871883392334
# > [Epoch 0] Current loss: 2.3507142066955566
# > [Epoch 0] Current loss: 2.4223599433898926
# > [Epoch 0] Current loss: 2.3328728675842285
# > [Epoch 0] Current loss: 1.8730663061141968
# > [Epoch 0] Current loss: 2.3497018814086914
# > [Epoch 0] Current loss: 2.27785062789917
# > [Epoch 0] Current loss: 2.4522252082824707
# > [Epoch 0] Current loss: 2.013711452484131
# > [Epoch 0] Current loss: 2.345001697540283
# > [Epoch 0] Current loss: 2.3217196464538574
# > [Epoch 0] Current loss: 2.337703227996826
# > [Epoch 0] Current loss: 2.298945665359497
# > [Epoch 0] Current loss: 1.911482810974121
# > [Epoch 0] Current loss: 2.417128324508667
# > [Epoch 0] Current loss: 2.294825792312622
# > [Epoch 0] Current loss: 2.339372158050537
# > [Epoch 0] Current loss: 2.1458804607391357
# > [Epoch 0] Current loss: 1.0574805736541748
# > [Epoch 0] Current loss: 1.3662458658218384
# > [Epoch 0] Current loss: 1.0742989778518677
# > [Epoch 0] Current loss: 1.6079301834106445
# > [Epoch 0] Current loss: 1.221623182296753
# > [Epoch 0] Current loss: 1.354162335395813
# > [Epoch 0] Current loss: 1.3097124099731445
# > [Epoch 0] Current loss: 1.5163522958755493
# > [Epoch 0] Current loss: 1.368617296218872
# > [Epoch 0] Current loss: 1.3752321004867554
# > [Epoch 0] Current loss: 1.341845154762268
# > [Epoch 0] Current loss: 1.110636591911316
# > [Epoch 0] Current loss: 0.941390872001648
# > [Epoch 0] Current loss: 1.3180572986602783
# > [Epoch 0] Current loss: 1.0891979932785034
# > [Epoch 0] Current loss: 1.2830487489700317
# > [Epoch 0] Current loss: 2.3819777965545654
# > [Epoch 0] Current loss: 2.2018280029296875
# > [Epoch 0] Current loss: 2.3441100120544434
# > [Epoch 0] Current loss: 2.0663914680480957
# > [Epoch 0] Current loss: 2.3288772106170654
# > [Epoch 0] Current loss: 2.1815006732940674
# > [Epoch 0] Current loss: 2.1498003005981445
# > [Epoch 0] Current loss: 2.062941074371338
# > [Epoch 0] Current loss: 1.8710603713989258
# > [Epoch 0] Current loss: 1.0856571197509766
# > [Epoch 0] Current loss: 1.5654582977294922
# > [Epoch 0] Current loss: 1.9300743341445923
# > [Epoch 0] Current loss: 1.3786766529083252
# > [Epoch 0] Current loss: 1.396514654159546
# > [Epoch 0] Current loss: 1.028637409210205
# > [Epoch 0] Current loss: 1.9900014400482178
# > [Epoch 0] Current loss: 0.9866907000541687
# > [Epoch 0] Current loss: 1.2028281688690186
# > [Epoch 0] Current loss: 0.8856748342514038
# > [Epoch 0] Current loss: 1.3593037128448486
# > [Epoch 0] Current loss: 1.6219803094863892
# > [Epoch 0] Current loss: 1.3187367916107178
# > [Epoch 0] Current loss: 1.085869550704956
# > [Epoch 0] Current loss: 0.7926148176193237
# > [Epoch 0] Current loss: 1.1841473579406738
# > [Epoch 0] Current loss: 1.7122936248779297
# > [Epoch 0] Current loss: 1.157428503036499
# > [Epoch 0] Current loss: 1.7072560787200928
# > [Epoch 0] Current loss: 1.3820552825927734
# > [Epoch 0] Current loss: 1.1475354433059692
# > [Epoch 0] Current loss: 1.0829718112945557
# > [Epoch 0] Current loss: 1.6766856908798218
# > [Epoch 0] Current loss: 1.3159788846969604
# > [Epoch 0] Current loss: 1.5362414121627808
# > [Epoch 0] Current loss: 1.6014684438705444
# > [Epoch 0] Current loss: 1.6344788074493408
# > [Epoch 0] Current loss: 1.200943112373352
# > [Epoch 0] Current loss: 1.0727293491363525
# > [Epoch 0] Current loss: 1.6354811191558838
# > [Epoch 0] Current loss: 1.5406769514083862
# > [Epoch 0] Current loss: 2.131303310394287
# > [Epoch 0] Current loss: 1.7586466073989868
# > [Epoch 0] Current loss: 1.2838302850723267
# > [Epoch 0] Current loss: 1.2196846008300781
# > [Epoch 0] Current loss: 1.1467390060424805
# > [Epoch 0] Current loss: 2.263017177581787
# > [Epoch 0] Current loss: 2.35636568069458
# > [Epoch 0] Current loss: 2.3083138465881348
# > [Epoch 0] Current loss: 2.3356003761291504
# > [Epoch 0] Current loss: 2.3797380924224854
# > [Epoch 0] Current loss: 2.3322372436523438
# > [Epoch 0] Current loss: 2.369964361190796
# > [Epoch 0] Current loss: 2.2352099418640137
# > [Epoch 0] Current loss: 2.3116705417633057
# > [Epoch 0] Current loss: 2.274843454360962
# > [Epoch 0] Current loss: 2.3516757488250732
# > [Epoch 0] Current loss: 1.216957449913025
# > [Epoch 0] Current loss: 1.0325334072113037
# > [Epoch 0] Current loss: 1.4156293869018555
# > [Epoch 0] Current loss: 1.059399127960205
# > [Epoch 0] Current loss: 1.0539772510528564
# > [Epoch 0] Current loss: 1.252138376235962
# > [Epoch 0] Current loss: 1.4790207147598267
# > [Epoch 0] Current loss: 1.0396720170974731
# > [Epoch 0] Current loss: 1.1897952556610107
# > [Epoch 0] Current loss: 1.3544865846633911
# > [Epoch 0] Current loss: 1.4001328945159912
# > [Epoch 0] Current loss: 0.8063488006591797
# > [Epoch 0] Current loss: 1.2425132989883423
# > [Epoch 0] Current loss: 1.3072690963745117
# > [Epoch 0] Current loss: 1.391586422920227
# > [Epoch 0] Current loss: 1.8238754272460938
# > [Epoch 0] Current loss: 1.3971686363220215
# > [Epoch 0] Current loss: 2.5030975341796875
# > [Epoch 0] Current loss: 2.084108591079712
# > [Epoch 0] Current loss: 1.0832089185714722
# > [Epoch 0] Current loss: 1.0898029804229736
# > [Epoch 0] Current loss: 1.2666807174682617
# > [Epoch 0] Current loss: 0.9243582487106323
# > [Epoch 0] Current loss: 1.7017629146575928
# > [Epoch 0] Current loss: 1.2368191480636597
# > [Epoch 0] Current loss: 0.809319794178009
# > [Epoch 0] Current loss: 1.304738163948059
# > [Epoch 0] Current loss: 1.226492166519165
# > [Epoch 0] Current loss: 1.824462890625
# > [Epoch 0] Current loss: 1.2840549945831299
# > [Epoch 0] Current loss: 1.835574746131897
# > [Epoch 0] Current loss: 1.0802667140960693
# > [Epoch 0] Current loss: 1.5078303813934326
# > [Epoch 0] Current loss: 1.317026138305664
# > [Epoch 0] Current loss: 1.5891740322113037
# > [Epoch 0] Current loss: 1.1202223300933838
# > [Epoch 0] Current loss: 1.2657952308654785
# > [Epoch 0] Current loss: 1.1454294919967651
# > [Epoch 0] Current loss: 1.6543077230453491
# > [Epoch 0] Current loss: 1.2736200094223022
# > [Epoch 0] Current loss: 1.5446693897247314
# > [Epoch 0] Current loss: 1.0887941122055054
# > [Epoch 0] Current loss: 0.8729140162467957
# > [Epoch 0] Current loss: 1.064944863319397
# > [Epoch 0] Current loss: 1.7992197275161743
# > [Epoch 0] Current loss: 0.9959144592285156
# > [Epoch 0] Current loss: 1.033601999282837
# > [Epoch 0] Current loss: 2.1857361793518066
# > [Epoch 0] Current loss: 0.830649197101593
# > [Epoch 0] Current loss: 1.3235658407211304
# > [Epoch 0] Current loss: 1.0258641242980957
# > [Epoch 0] Current loss: 0.863703727722168
# > [Epoch 0] Current loss: 1.1609443426132202
# > [Epoch 0] Current loss: 1.3668116331100464
# > [Epoch 0] Current loss: 1.2100896835327148
# > [Epoch 0] Current loss: 2.4656238555908203
# > [Epoch 0] Current loss: 1.1505162715911865
# > [Epoch 0] Current loss: 1.9154891967773438
# > [Epoch 0] Current loss: 1.06065034866333
# > [Epoch 0] Current loss: 1.161309003829956
# > [Epoch 0] Current loss: 0.9436048269271851
# > [Epoch 0] Current loss: 1.5549267530441284
# > [Epoch 0] Current loss: 1.1021828651428223
# > [Epoch 0] Current loss: 0.9629206657409668
# > [Epoch 0] Current loss: 0.973957359790802
# > [Epoch 0] Current loss: 1.0601270198822021
# > [Epoch 0] Current loss: 1.5200538635253906
# > [Epoch 0] Current loss: 1.019059419631958
# > [Epoch 0] Current loss: 1.2174263000488281
# > [Epoch 0] Current loss: 1.1847928762435913
# > [Epoch 0] Current loss: 1.0849502086639404
# > [Epoch 0] Current loss: 1.145129919052124
# > [Epoch 0] Current loss: 2.2774221897125244
# > [Epoch 0] Current loss: 1.1740869283676147
# > [Epoch 0] Current loss: 2.0528581142425537
# > [Epoch 0] Current loss: 0.9289973974227905
# > [Epoch 0] Current loss: 1.159067153930664
# > [Epoch 0] Current loss: 1.137935757637024
# > [Epoch 0] Current loss: 0.9909098744392395
# > [Epoch 0] Current loss: 1.8531767129898071
# > [Epoch 0] Current loss: 1.6748952865600586
# > [Epoch 0] Current loss: 2.023728847503662
# > [Epoch 0] Current loss: 1.1910121440887451
# > [Epoch 0] Current loss: 1.4205584526062012
# > [Epoch 0] Current loss: 0.8757117390632629
# > [Epoch 0] Current loss: 1.2519060373306274
# > [Epoch 0] Current loss: 1.052477240562439
# > [Epoch 0] Current loss: 1.287445306777954
# > [Epoch 0] Current loss: 0.9271171689033508
# > [Epoch 0] Current loss: 1.2456424236297607
# > [Epoch 0] Current loss: 1.1860790252685547
# > [Epoch 0] Current loss: 1.2682934999465942
# > [Epoch 0] Current loss: 2.311729907989502
# > [Epoch 0] Current loss: 2.3439297676086426
# > [Epoch 0] Current loss: 2.423154354095459
# > [Epoch 0] Current loss: 2.2919838428497314
# > [Epoch 0] Current loss: 1.2106221914291382
# > [Epoch 0] Current loss: 1.5262014865875244
# > [Epoch 0] Current loss: 1.7433414459228516
# > [Epoch 0] Current loss: 1.5838706493377686
# > [Epoch 0] Current loss: 1.5549216270446777
# > [Epoch 0] Current loss: 1.2015578746795654
# > [Epoch 0] Current loss: 1.3046233654022217
# > [Epoch 0] Current loss: 1.743472695350647
# > [Epoch 0] Current loss: 1.2091548442840576
# > [Epoch 0] Current loss: 1.6359401941299438
# > [Epoch 0] Current loss: 1.1919324398040771
# > [Epoch 0] Current loss: 1.5760619640350342
# > [Epoch 0] Current loss: 1.2078759670257568
# > [Epoch 0] Current loss: 1.8259856700897217
# > [Epoch 0] Current loss: 1.2662969827651978
# > [Epoch 0] Current loss: 1.7166547775268555
# > [Epoch 0] Current loss: 2.054809331893921
# > [Epoch 0] Current loss: 1.7043260335922241
# > [Epoch 0] Current loss: 1.2437231540679932
# > [Epoch 0] Current loss: 1.1946275234222412
# > [Epoch 0] Current loss: 1.478948712348938
# > [Epoch 0] Current loss: 1.3495714664459229
# > [Epoch 0] Current loss: 1.2084983587265015
# > [Epoch 0] Current loss: 1.4145338535308838
# > [Epoch 0] Current loss: 1.449836015701294
# > [Epoch 0] Current loss: 1.2843520641326904
# > [Epoch 0] Current loss: 1.5443196296691895
# > [Epoch 0] Current loss: 0.8110077977180481
# > [Epoch 0] Current loss: 1.902897596359253
# > [Epoch 0] Current loss: 1.289355993270874
# > [Epoch 0] Current loss: 1.5690556764602661
# > [Epoch 0] Current loss: 0.9429952502250671
# > [Epoch 0] Current loss: 1.1554433107376099
# > [Epoch 0] Current loss: 1.0295274257659912
# > [Epoch 0] Current loss: 0.9747953414916992
# > [Epoch 0] Current loss: 1.1066677570343018
# > [Epoch 0] Current loss: 1.1481602191925049
# > [Epoch 0] Current loss: 1.8421615362167358
# > [Epoch 0] Current loss: 0.8705263137817383
# > [Epoch 0] Current loss: 1.9650108814239502
# > [Epoch 0] Current loss: 1.0501199960708618
# > [Epoch 0] Current loss: 1.6374523639678955
# > [Epoch 0] Current loss: 1.4283397197723389
# > [Epoch 0] Current loss: 1.1676831245422363
# > [Epoch 0] Current loss: 1.2495479583740234
# > [Epoch 0] Current loss: 1.0229098796844482
# > [Epoch 0] Current loss: 1.6157643795013428
# > [Epoch 0] Current loss: 1.1715805530548096
# > [Epoch 0] Current loss: 1.285036325454712
# > [Epoch 0] Current loss: 1.6739418506622314
# > [Epoch 0] Current loss: 1.448574185371399
# > [Epoch 0] Current loss: 1.0220630168914795
# > [Epoch 0] Current loss: 0.9583173990249634
# > [Epoch 0] Current loss: 1.2324775457382202
# > [Epoch 0] Current loss: 1.5853629112243652
# > [Epoch 0] Current loss: 1.5429123640060425
# > [Epoch 0] Current loss: 1.8123594522476196
# > [Epoch 0] Current loss: 1.496865153312683
# > [Epoch 0] Current loss: 1.2101746797561646
# > [Epoch 0] Current loss: 1.2881416082382202
# > [Epoch 0] Current loss: 1.027066946029663
# > [Epoch 0] Current loss: 1.1516201496124268
# > [Epoch 0] Current loss: 1.2556782960891724
# > [Epoch 0] Current loss: 1.3972080945968628
# > [Epoch 0] Current loss: 1.144943118095398
# > [Epoch 0] Current loss: 1.2827030420303345
# > [Epoch 0] Current loss: 1.7987054586410522
# > [Epoch 0] Current loss: 1.6375350952148438
# > [Epoch 0] Current loss: 1.0636084079742432
# > [Epoch 0] Current loss: 1.3736644983291626
# > [Epoch 0] Current loss: 1.0335118770599365
# > [Epoch 0] Current loss: 1.0500988960266113
# > [Epoch 0] Current loss: 1.427633285522461
# > [Epoch 0] Current loss: 1.7156760692596436
# > [Epoch 0] Current loss: 1.3135313987731934
# > [Epoch 0] Current loss: 1.6166331768035889
# > [Epoch 0] Current loss: 1.468662977218628
# > [Epoch 0] Current loss: 1.3798717260360718
# > [Epoch 0] Current loss: 1.0529961585998535
# > [Epoch 0] Current loss: 1.2268223762512207
# > [Epoch 0] Current loss: 1.8035857677459717
# > [Epoch 0] Current loss: 1.0465638637542725
# > [Epoch 0] Current loss: 1.50913667678833
# > [Epoch 0] Current loss: 0.9982932209968567
# > [Epoch 0] Current loss: 1.2421658039093018
# > [Epoch 0] Current loss: 1.7039216756820679
# > [Epoch 0] Current loss: 0.7843453288078308
# > [Epoch 0] Current loss: 1.6962474584579468
# > [Epoch 0] Current loss: 1.003212571144104
# > [Epoch 0] Current loss: 1.2915635108947754
# > [Epoch 0] Current loss: 0.9845494031906128
# > [Epoch 0] Current loss: 1.4377063512802124
# > [Epoch 0] Current loss: 2.2053112983703613
# > [Epoch 0] Current loss: 1.6332473754882812
# > [Epoch 0] Current loss: 1.7579574584960938
# > [Epoch 0] Current loss: 1.5353128910064697
# > [Epoch 0] Current loss: 1.5056209564208984
# > [Epoch 0] Current loss: 1.3505736589431763
# > [Epoch 0] Current loss: 1.1951699256896973
# > [Epoch 0] Current loss: 1.0464801788330078
# > [Epoch 0] Current loss: 1.6161119937896729
# > [Epoch 0] Current loss: 1.3779330253601074
# > [Epoch 0] Current loss: 1.715619444847107
# > [Epoch 0] Current loss: 2.0509538650512695
# > [Epoch 0] Current loss: 1.7091658115386963
# > [Epoch 0] Current loss: 1.03351891040802
# > [Epoch 0] Current loss: 1.0986660718917847
# > [Epoch 0] Current loss: 1.4042584896087646
# > [Epoch 0] Current loss: 0.8740652799606323
# > [Epoch 0] Current loss: 1.3458905220031738
# > [Epoch 0] Current loss: 1.2135944366455078
# > [Epoch 0] Current loss: 1.4471380710601807
# > [Epoch 0] Current loss: 1.3763067722320557
# > [Epoch 0] Current loss: 1.8260362148284912
# > [Epoch 0] Current loss: 1.3498141765594482
# > [Epoch 0] Current loss: 1.3124651908874512
# > [Epoch 0] Current loss: 1.201781153678894
# > [Epoch 0] Current loss: 1.1238224506378174
# > [Epoch 0] Current loss: 1.177689552307129
# > [Epoch 0] Current loss: 1.7665913105010986
# > [Epoch 0] Current loss: 1.3305367231369019
# > [Epoch 0] Current loss: 1.1108676195144653
# > [Epoch 0] Current loss: 1.6428810358047485
# > [Epoch 0] Current loss: 0.9964895248413086
# > [Epoch 0] Current loss: 1.4528266191482544
# > [Epoch 0] Current loss: 1.7451814413070679
# > [Epoch 0] Current loss: 1.3761212825775146
# > [Epoch 0] Current loss: 1.0713493824005127
# > [Epoch 0] Current loss: 1.4761264324188232
# > [Epoch 0] Current loss: 1.102311372756958
# > [Epoch 0] Current loss: 0.9631890058517456
# > [Epoch 0] Current loss: 0.9605234861373901
# > [Epoch 0] Current loss: 2.028557777404785
# > [Epoch 0] Current loss: 1.1619406938552856
# > [Epoch 0] Current loss: 2.0118536949157715
# > [Epoch 0] Current loss: 1.491884469985962
# > [Epoch 0] Current loss: 0.9380636215209961
# > [Epoch 0] Current loss: 2.2533090114593506
# > [Epoch 0] Current loss: 1.087343692779541
# > [Epoch 0] Current loss: 1.2799715995788574
# > [Epoch 0] Current loss: 1.4546306133270264
# > [Epoch 0] Current loss: 2.320693016052246
# > [Epoch 0] Current loss: 2.3537042140960693
# > [Epoch 0] Current loss: 2.442866802215576
# > [Epoch 0] Current loss: 2.2815308570861816
# > [Epoch 0] Current loss: 1.3420147895812988
# > [Epoch 0] Current loss: 0.9008529782295227
# > [Epoch 0] Current loss: 1.7037115097045898
# > [Epoch 0] Current loss: 1.2004098892211914
# > [Epoch 0] Current loss: 1.8429992198944092
# > [Epoch 0] Current loss: 1.4269208908081055
# > [Epoch 0] Current loss: 0.9798574447631836
# > [Epoch 0] Current loss: 0.7593362927436829
# > [Epoch 0] Current loss: 1.9274505376815796
# > [Epoch 0] Current loss: 2.278099775314331
# > [Epoch 0] Current loss: 2.270158052444458
# > [Epoch 0] Current loss: 2.2608838081359863
# > [Epoch 0] Current loss: 2.2819504737854004
# > [Epoch 0] Current loss: 2.3120694160461426
# > [Epoch 0] Current loss: 2.2792763710021973
# > [Epoch 0] Current loss: 2.333568811416626
# > [Epoch 0] Current loss: 2.3243820667266846
# > [Epoch 0] Current loss: 2.301942825317383
# > [Epoch 0] Current loss: 2.4061942100524902
# > [Epoch 0] Current loss: 2.349804639816284
# > [Epoch 0] Current loss: 2.2894489765167236
# > [Epoch 0] Current loss: 2.336973190307617
# > [Epoch 0] Current loss: 2.364893674850464
# > [Epoch 0] Current loss: 2.3133223056793213
# > [Epoch 0] Current loss: 2.24131178855896
# > [Epoch 0] Current loss: 2.340698719024658
# > [Epoch 0] Current loss: 2.3472142219543457
# > [Epoch 0] Current loss: 2.381376266479492
# > [Epoch 0] Current loss: 2.4012084007263184
# > [Epoch 0] Current loss: 2.3243727684020996
# > [Epoch 0] Current loss: 2.3414406776428223
# > [Epoch 0] Current loss: 2.350475549697876
# > [Epoch 0] Current loss: 2.2683053016662598
# > [Epoch 0] Current loss: 2.3353190422058105
# > [Epoch 0] Current loss: 2.356213092803955
# > [Epoch 0] Current loss: 2.3501462936401367
# > [Epoch 0] Current loss: 2.465205192565918
# > [Epoch 0] Current loss: 2.3589401245117188
# > [Epoch 0] Current loss: 2.3577427864074707
# > [Epoch 0] Current loss: 2.3814167976379395
# > [Epoch 0] Current loss: 2.30607271194458
# > [Epoch 0] Current loss: 2.2345519065856934
# > [Epoch 0] Current loss: 2.3604817390441895
# > [Epoch 0] Current loss: 2.3358538150787354
# > [Epoch 0] Current loss: 2.4306416511535645
# > [Epoch 0] Current loss: 2.2991251945495605
# > [Epoch 0] Current loss: 2.305764675140381
# > [Epoch 0] Current loss: 2.3520267009735107
# > [Epoch 0] Current loss: 2.2994847297668457
# > [Epoch 0] Current loss: 2.439791440963745
# > [Epoch 0] Current loss: 1.3462820053100586
# > [Epoch 0] Current loss: 1.386499285697937
# > [Epoch 0] Current loss: 0.9049085378646851
# > [Epoch 0] Current loss: 1.3863599300384521
# > [Epoch 0] Current loss: 1.003250002861023
# > [Epoch 0] Current loss: 1.164698839187622
# > [Epoch 0] Current loss: 0.7504461407661438
# > [Epoch 0] Current loss: 1.3973095417022705
# > [Epoch 0] Current loss: 0.7608901262283325
# > [Epoch 0] Current loss: 1.3851679563522339
# > [Epoch 0] Current loss: 0.8234826326370239
# > [Epoch 0] Current loss: 1.4210503101348877
# > [Epoch 0] Current loss: 1.3784635066986084
# > [Epoch 0] Current loss: 0.9908076524734497
# > [Epoch 0] Current loss: 0.8568464517593384
# > [Epoch 0] Current loss: 1.0589901208877563
# > [Epoch 0] Current loss: 1.2507703304290771
# > [Epoch 0] Current loss: 1.6244653463363647
# > [Epoch 0] Current loss: 1.3174763917922974
# > [Epoch 0] Current loss: 1.2381044626235962
# > [Epoch 0] Current loss: 0.7567892074584961
# > [Epoch 0] Current loss: 1.5445700883865356
# > [Epoch 0] Current loss: 1.22599196434021
# > [Epoch 0] Current loss: 0.8888369798660278
# > [Epoch 0] Current loss: 1.4139068126678467
# > [Epoch 0] Current loss: 0.9024304151535034
# > [Epoch 0] Current loss: 1.8062387704849243
# > [Epoch 0] Current loss: 1.8704392910003662
# > [Epoch 0] Current loss: 1.5607415437698364
# > [Epoch 0] Current loss: 1.0711824893951416
# > [Epoch 0] Current loss: 1.4506944417953491
# > [Epoch 0] Current loss: 0.9728555679321289
# > [Epoch 0] Current loss: 0.9274191856384277
# > [Epoch 0] Current loss: 0.6035268306732178
# > [Epoch 0] Current loss: 1.1239421367645264
# > [Epoch 0] Current loss: 1.385021448135376
# > [Epoch 0] Current loss: 1.147498369216919
# > [Epoch 0] Current loss: 1.3675981760025024
# > [Epoch 0] Current loss: 1.2707128524780273
# > [Epoch 0] Current loss: 1.264052152633667
# > [Epoch 0] Current loss: 1.5628572702407837
# > [Epoch 0] Current loss: 1.642881989479065
# > [Epoch 0] Current loss: 0.8217393159866333
# > [Epoch 0] Current loss: 2.019902467727661
# > [Epoch 0] Current loss: 1.3712016344070435
# > [Epoch 0] Current loss: 2.2136635780334473
# > [Epoch 0] Current loss: 2.111583948135376
# > [Epoch 0] Current loss: 1.0386593341827393
# > [Epoch 0] Current loss: 1.1348865032196045
# > [Epoch 0] Current loss: 1.245544195175171
# > [Epoch 0] Current loss: 1.3349875211715698
# > [Epoch 0] Current loss: 1.387039303779602
# > [Epoch 0] Current loss: 1.1593964099884033
# > [Epoch 0] Current loss: 2.3838610649108887
# > [Epoch 0] Current loss: 2.1410021781921387
# > [Epoch 0] Current loss: 2.155989170074463
# > [Epoch 0] Current loss: 1.1079127788543701
# > [Epoch 0] Current loss: 1.7231613397598267
# > [Epoch 0] Current loss: 1.8526493310928345
# > [Epoch 0] Current loss: 0.9740194082260132
# > [Epoch 0] Current loss: 1.8172107934951782
# > [Epoch 0] Current loss: 0.8246939778327942
# > [Epoch 0] Current loss: 0.8922139406204224
# > [Epoch 0] Current loss: 1.6601778268814087
# > [Epoch 0] Current loss: 2.023975372314453
# > [Epoch 0] Current loss: 2.507422924041748
# > [Epoch 0] Current loss: 0.8693974614143372
# > [Epoch 0] Current loss: 1.000901699066162
# > [Epoch 0] Current loss: 1.7322731018066406
# > [Epoch 0] Current loss: 2.2796425819396973
# > [Epoch 0] Current loss: 1.7121241092681885
# > [Epoch 0] Current loss: 1.5174661874771118
# > [Epoch 0] Current loss: 0.7128553986549377
# > [Epoch 0] Current loss: 1.4473621845245361
# > [Epoch 0] Current loss: 1.3527204990386963
# > [Epoch 0] Current loss: 1.269466519355774
# > [Epoch 0] Current loss: 1.1732580661773682
# > [Epoch 0] Current loss: 0.8066652417182922
# > [Epoch 0] Current loss: 1.5287744998931885
# > [Epoch 0] Current loss: 0.7233478426933289
# > [Epoch 0] Current loss: 0.9969887733459473
# > [Epoch 0] Current loss: 1.127181887626648
# > [Epoch 0] Current loss: 0.8920669555664062
# > [Epoch 0] Current loss: 1.331773042678833
# > [Epoch 0] Current loss: 0.9795920252799988
# > [Epoch 0] Current loss: 1.038254976272583
# > [Epoch 0] Current loss: 1.0049766302108765
# > [Epoch 0] Current loss: 0.7239084243774414
# > [Epoch 0] Current loss: 1.1921753883361816
# > [Epoch 0] Current loss: 0.9433814287185669
# > [Epoch 0] Current loss: 1.5991344451904297
# > [Epoch 0] Current loss: 1.1819545030593872
# > [Epoch 0] Current loss: 0.8759822845458984
# > [Epoch 0] Current loss: 0.748764157295227
# > [Epoch 0] Current loss: 0.8528456687927246
# > [Epoch 0] Current loss: 1.1152856349945068
# > [Epoch 0] Current loss: 0.9585490226745605
# > [Epoch 0] Current loss: 0.9572492837905884
# > [Epoch 0] Current loss: 0.9323299527168274
# > [Epoch 0] Current loss: 1.0320675373077393
# > [Epoch 0] Current loss: 1.2572301626205444
# > [Epoch 0] Current loss: 1.3127049207687378
# > [Epoch 0] Current loss: 0.877025306224823
# > [Epoch 0] Current loss: 1.1537315845489502
# > [Epoch 0] Current loss: 1.5299477577209473
# > [Epoch 0] Current loss: 0.8567692637443542
# > [Epoch 0] Current loss: 0.8221248388290405
# > [Epoch 0] Current loss: 1.3433890342712402
# > [Epoch 0] Current loss: 0.8455243110656738
# > [Epoch 0] Current loss: 0.8094550967216492
# > [Epoch 0] Current loss: 2.0706582069396973
# > [Epoch 0] Current loss: 1.8672443628311157
# > [Epoch 0] Current loss: 1.9172742366790771
# > [Epoch 0] Current loss: 1.6256296634674072
# > [Epoch 0] Current loss: 1.5651565790176392
# > [Epoch 0] Current loss: 0.7395068407058716
# > [Epoch 0] Current loss: 1.0306026935577393
# > [Epoch 0] Current loss: 2.0009140968322754
# > [Epoch 0] Current loss: 0.8848400115966797
# > [Epoch 0] Current loss: 1.6484454870224
# > [Epoch 0] Current loss: 1.6862274408340454
# > [Epoch 0] Current loss: 1.240058183670044
# > [Epoch 0] Current loss: 1.2032363414764404
# > [Epoch 0] Current loss: 0.8094750642776489
# > [Epoch 0] Current loss: 0.8442599177360535
# > [Epoch 0] Current loss: 1.0620065927505493
# > [Epoch 0] Current loss: 1.6338717937469482
# > [Epoch 0] Current loss: 1.2928990125656128
# > [Epoch 0] Current loss: 1.6875114440917969
# > [Epoch 0] Current loss: 1.958595871925354
# > [Epoch 0] Current loss: 1.89468514919281
# > [Epoch 0] Current loss: 1.021203637123108
# > [Epoch 0] Current loss: 1.3374508619308472
# > [Epoch 0] Current loss: 1.5952790975570679
# > [Epoch 0] Current loss: 0.9364945292472839
# > [Epoch 0] Current loss: 1.4615446329116821
# > [Epoch 0] Current loss: 0.8450956344604492
# > [Epoch 0] Current loss: 0.8159602284431458
# > [Epoch 0] Current loss: 1.262623906135559
# > [Epoch 0] Current loss: 0.7128076553344727
# > [Epoch 0] Current loss: 1.1014028787612915
# Iteration:   0%|          | 0/545 [00:00<?, ?it/s]
# > [Epoch 1] Current loss: 1.5021082162857056
# > [Epoch 1] Current loss: 1.4780657291412354
# > [Epoch 1] Current loss: 1.291349172592163
# > [Epoch 1] Current loss: 1.1621007919311523
# > [Epoch 1] Current loss: 1.0283396244049072
# > [Epoch 1] Current loss: 1.0029467344284058
# > [Epoch 1] Current loss: 1.5177440643310547
# > [Epoch 1] Current loss: 1.3794138431549072
# > [Epoch 1] Current loss: 1.616805076599121
# > [Epoch 1] Current loss: 1.8005434274673462
# > [Epoch 1] Current loss: 2.352266311645508
# > [Epoch 1] Current loss: 2.3422789573669434
# > [Epoch 1] Current loss: 2.263824701309204
# > [Epoch 1] Current loss: 1.8562850952148438
# > [Epoch 1] Current loss: 2.3466315269470215
# > [Epoch 1] Current loss: 2.3370862007141113
# > [Epoch 1] Current loss: 2.3952319622039795
# > [Epoch 1] Current loss: 2.3627753257751465
# > [Epoch 1] Current loss: 2.271353006362915
# > [Epoch 1] Current loss: 2.335731029510498
# > [Epoch 1] Current loss: 2.310213565826416
# > [Epoch 1] Current loss: 2.3229804039001465
# > [Epoch 1] Current loss: 1.8898006677627563
# > [Epoch 1] Current loss: 2.355832099914551
# > [Epoch 1] Current loss: 2.350405693054199
# > [Epoch 1] Current loss: 2.3964366912841797
# > [Epoch 1] Current loss: 2.3325791358947754
# > [Epoch 1] Current loss: 1.8025941848754883
# > [Epoch 1] Current loss: 2.3135008811950684
# > [Epoch 1] Current loss: 2.2763311862945557
# > [Epoch 1] Current loss: 2.4271388053894043
# > [Epoch 1] Current loss: 1.9899718761444092
# > [Epoch 1] Current loss: 2.3448472023010254
# > [Epoch 1] Current loss: 2.2996444702148438
# > [Epoch 1] Current loss: 2.3172872066497803
# > [Epoch 1] Current loss: 2.2921979427337646
# > [Epoch 1] Current loss: 1.8930444717407227
# > [Epoch 1] Current loss: 2.406461238861084
# > [Epoch 1] Current loss: 2.2822299003601074
# > [Epoch 1] Current loss: 2.3391075134277344
# > [Epoch 1] Current loss: 2.0020558834075928
# > [Epoch 1] Current loss: 1.0028613805770874
# > [Epoch 1] Current loss: 1.311755895614624
# > [Epoch 1] Current loss: 1.037032127380371
# > [Epoch 1] Current loss: 1.5534865856170654
# > [Epoch 1] Current loss: 1.2041337490081787
# > [Epoch 1] Current loss: 1.3046694993972778
# > [Epoch 1] Current loss: 1.2663888931274414
# > [Epoch 1] Current loss: 1.483216404914856
# > [Epoch 1] Current loss: 1.2774988412857056
# > [Epoch 1] Current loss: 1.3612086772918701
# > [Epoch 1] Current loss: 1.3168359994888306
# > [Epoch 1] Current loss: 1.0455518960952759
# > [Epoch 1] Current loss: 0.9254012107849121
# > [Epoch 1] Current loss: 1.2746061086654663
# > [Epoch 1] Current loss: 0.997623085975647
# > [Epoch 1] Current loss: 1.2300143241882324
# > [Epoch 1] Current loss: 2.365755796432495
# > [Epoch 1] Current loss: 2.178194522857666
# > [Epoch 1] Current loss: 2.333428382873535
# > [Epoch 1] Current loss: 2.0268783569335938
# > [Epoch 1] Current loss: 2.311284303665161
# > [Epoch 1] Current loss: 2.148470163345337
# > [Epoch 1] Current loss: 2.1151175498962402
# > [Epoch 1] Current loss: 2.0215396881103516
# > [Epoch 1] Current loss: 1.8092702627182007
# > [Epoch 1] Current loss: 1.0457546710968018
# > [Epoch 1] Current loss: 1.5306742191314697
# > [Epoch 1] Current loss: 1.8865549564361572
# > [Epoch 1] Current loss: 1.3794697523117065
# > [Epoch 1] Current loss: 1.3681604862213135
# > [Epoch 1] Current loss: 1.0197194814682007
# > [Epoch 1] Current loss: 1.9843928813934326
# > [Epoch 1] Current loss: 0.9449179768562317
# > [Epoch 1] Current loss: 1.1304001808166504
# > [Epoch 1] Current loss: 0.8607085943222046
# > [Epoch 1] Current loss: 1.3201541900634766
# > [Epoch 1] Current loss: 1.58864164352417
# > [Epoch 1] Current loss: 1.2460137605667114
# > [Epoch 1] Current loss: 1.03860604763031
# > [Epoch 1] Current loss: 0.7453161478042603
# > [Epoch 1] Current loss: 1.1253137588500977
# > [Epoch 1] Current loss: 1.7094767093658447
# > [Epoch 1] Current loss: 1.110738754272461
# > [Epoch 1] Current loss: 1.6999762058258057
# > [Epoch 1] Current loss: 1.3480732440948486
# > [Epoch 1] Current loss: 1.0574404001235962
# > [Epoch 1] Current loss: 1.0549205541610718
# > [Epoch 1] Current loss: 1.6372289657592773
# > [Epoch 1] Current loss: 1.2897003889083862
# > [Epoch 1] Current loss: 1.5015345811843872
# > [Epoch 1] Current loss: 1.5770704746246338
# > [Epoch 1] Current loss: 1.5762962102890015
# > [Epoch 1] Current loss: 1.1729848384857178
# > [Epoch 1] Current loss: 1.0333244800567627
# > [Epoch 1] Current loss: 1.6117416620254517
# > [Epoch 1] Current loss: 1.5182435512542725
# > [Epoch 1] Current loss: 2.0402474403381348
# > [Epoch 1] Current loss: 1.7192083597183228
# > [Epoch 1] Current loss: 1.2231847047805786
# > [Epoch 1] Current loss: 1.171999454498291
# > [Epoch 1] Current loss: 1.0370322465896606
# > [Epoch 1] Current loss: 2.2411954402923584
# > [Epoch 1] Current loss: 2.349400281906128
# > [Epoch 1] Current loss: 2.2791593074798584
# > [Epoch 1] Current loss: 2.327770948410034
# > [Epoch 1] Current loss: 2.373232841491699
# > [Epoch 1] Current loss: 2.3197860717773438
# > [Epoch 1] Current loss: 2.365785837173462
# > [Epoch 1] Current loss: 2.222663164138794
# > [Epoch 1] Current loss: 2.3013575077056885
# > [Epoch 1] Current loss: 2.2706387042999268
# > [Epoch 1] Current loss: 2.3322854042053223
# > [Epoch 1] Current loss: 1.175949215888977
# > [Epoch 1] Current loss: 0.9755172729492188
# > [Epoch 1] Current loss: 1.3818418979644775
# > [Epoch 1] Current loss: 1.0255076885223389
# > [Epoch 1] Current loss: 1.0297704935073853
# > [Epoch 1] Current loss: 1.2349154949188232
# > [Epoch 1] Current loss: 1.4520705938339233
# > [Epoch 1] Current loss: 1.0139977931976318
# > [Epoch 1] Current loss: 1.1469453573226929
# > [Epoch 1] Current loss: 1.340272307395935
# > [Epoch 1] Current loss: 1.3733291625976562
# > [Epoch 1] Current loss: 0.8036969900131226
# > [Epoch 1] Current loss: 1.1972277164459229
# > [Epoch 1] Current loss: 1.2899760007858276
# > [Epoch 1] Current loss: 1.362889051437378
# > [Epoch 1] Current loss: 1.8367236852645874
# > [Epoch 1] Current loss: 1.3970693349838257
# > [Epoch 1] Current loss: 2.521749258041382
# > [Epoch 1] Current loss: 2.1159684658050537
# > [Epoch 1] Current loss: 1.0547313690185547
# > [Epoch 1] Current loss: 1.0206820964813232
# > [Epoch 1] Current loss: 1.2446324825286865
# > [Epoch 1] Current loss: 0.8985331654548645
# > [Epoch 1] Current loss: 1.6778618097305298
# > [Epoch 1] Current loss: 1.20663583278656
# > [Epoch 1] Current loss: 0.7842690348625183
# > [Epoch 1] Current loss: 1.2463079690933228
# > [Epoch 1] Current loss: 1.194602608680725
# > [Epoch 1] Current loss: 1.7918977737426758
# > [Epoch 1] Current loss: 1.2111740112304688
# > [Epoch 1] Current loss: 1.8138988018035889
# > [Epoch 1] Current loss: 1.0482162237167358
# > [Epoch 1] Current loss: 1.445064902305603
# > [Epoch 1] Current loss: 1.3123975992202759
# > [Epoch 1] Current loss: 1.547549843788147
# > [Epoch 1] Current loss: 1.0590697526931763
# > [Epoch 1] Current loss: 1.210237741470337
# > [Epoch 1] Current loss: 1.0904693603515625
# > [Epoch 1] Current loss: 1.6386020183563232
# > [Epoch 1] Current loss: 1.2500779628753662
# > [Epoch 1] Current loss: 1.5313678979873657
# > [Epoch 1] Current loss: 1.06864333152771
# > [Epoch 1] Current loss: 0.842679500579834
# > [Epoch 1] Current loss: 1.0297820568084717
# > [Epoch 1] Current loss: 1.7665876150131226
# > [Epoch 1] Current loss: 0.9585345387458801
# > [Epoch 1] Current loss: 0.9996878504753113
# > [Epoch 1] Current loss: 2.1584994792938232
# > [Epoch 1] Current loss: 0.8137580156326294
# > [Epoch 1] Current loss: 1.3106725215911865
# > [Epoch 1] Current loss: 1.003389835357666
# > [Epoch 1] Current loss: 0.8466342687606812
# > [Epoch 1] Current loss: 1.1298952102661133
# > [Epoch 1] Current loss: 1.3634713888168335
# > [Epoch 1] Current loss: 1.2136752605438232
# > [Epoch 1] Current loss: 2.4276366233825684
# > [Epoch 1] Current loss: 1.1216078996658325
# > [Epoch 1] Current loss: 1.9117295742034912
# > [Epoch 1] Current loss: 1.036422848701477
# > [Epoch 1] Current loss: 1.1149985790252686
# > [Epoch 1] Current loss: 0.9157009124755859
# > [Epoch 1] Current loss: 1.583956241607666
# > [Epoch 1] Current loss: 1.1012132167816162

# %%
embed_model = finetune_engine.get_finetuned_model()

# Or, import model from the directory whenever required.
#from llama_index.core.embeddings import LinearAdapterEmbeddingModel
#embed_model = LinearAdapterEmbeddingModel(base_embed_model, "model_output_test")

# %%
embed_model

# %% [markdown]
# ## Fine tuning OpenAI Embedding Model using Adapter method

# %%
from llama_index.finetuning import EmbeddingAdapterFinetuneEngine
from llama_index.embeddings.openai import OpenAIEmbedding

openai_finetune_engine = EmbeddingAdapterFinetuneEngine(
    TRAIN_DATASET,
    OpenAIEmbedding(model="text-embedding-3-small"),
    model_output_path="model_output_test_openai",
    bias=True,
    epochs=2,
    verbose=True,
)

# %%
openai_finetune_engine.finetune()

openai_embed_model = openai_finetune_engine.get_finetuned_model()

# %%
openai_embed_model

# %% [markdown]
# # Evaluate

# %% [markdown]
# ## Define the Evaluation Functions

# %%
from llama_index.core import ServiceContext, VectorStoreIndex
from llama_index.core.schema import TextNode
from tqdm import tqdm
import pandas as pd

def evaluate(dataset, embed_model, top_k=5, verbose=False):
    corpus = dataset.corpus
    queries = dataset.queries
    relevant_docs = dataset.relevant_docs

    # Chunking the documents and generating embeddings
    service_context = ServiceContext.from_defaults(embed_model=embed_model)
    nodes = [TextNode(id_=id_, text=text) for id_, text in corpus.items()]
    index = VectorStoreIndex(nodes, service_context=service_context, show_progress=True)

    # Define a retriever to answer the questions
    retriever = index.as_retriever(similarity_top_k=top_k)

    eval_results = []

    # Look into each response sources to see if the chunk that contains the answer is retrieved.
    for query_id, query in tqdm(queries.items()):
        retrieved_nodes = retriever.retrieve(query)
        retrieved_ids = [node.node.node_id for node in retrieved_nodes]
        expected_id = relevant_docs[query_id][0]

        try:
            rank = retrieved_ids.index(expected_id) + 1
            reciprocal_rank = 1 / rank
        except ValueError:
            rank = None
            reciprocal_rank = 0

        is_hit = expected_id in retrieved_ids

        eval_result = {
            "is_hit": is_hit,
            "retrieved": retrieved_ids,
            "expected": expected_id,
            "query": query_id,
            "rank": rank,
            "reciprocal_rank": reciprocal_rank
        }
        eval_results.append(eval_result)

    return eval_results

# %% [markdown]
# ## OpenAI Embedding Model Evaluation

# %%
# Load the OpenAI Ada model and evaluate it.
openai_text_embedding_small = OpenAIEmbedding(model="text-embedding-3-small")
openai_embedding_val_results = evaluate(VALIDATION_DATASET, openai_text_embedding_small)
# Out:
# <ipython-input-18-c34e84fce376>:12: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(embed_model=embed_model)
# Generating embeddings:   0%|          | 0/248 [00:00<?, ?it/s]
# 100%|██████████| 496/496 [02:29<00:00,  3.32it/s]

# %%
openai_embedding_val_results = [
    result for result in openai_embedding_val_results if isinstance(result, dict)
]

df_openai = pd.DataFrame(openai_embedding_val_results)

hit_rate_openai = df_openai["is_hit"].mean()
mrr_openai = df_openai["reciprocal_rank"].mean()

print(f"Hit rate: {hit_rate_openai}")
print(f"MRR: {mrr_openai}")
# Out:
# Hit rate: 0.9354838709677419
# MRR: 0.787869623655914

# %% [markdown]
# ### OpenAI Embedding Model with Fine Tuned Adapter Model Evaluation

# %%
from llama_index.legacy.embeddings.adapter import LinearAdapterEmbeddingModel

openai_text_embedding_small = OpenAIEmbedding(model="text-embedding-3-small")
openai_embed_model = LinearAdapterEmbeddingModel(openai_text_embedding_small, "model_output_test_openai")

val_results_ft_openai = evaluate(VALIDATION_DATASET, openai_embed_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/llama_index/legacy/embeddings/adapter_utils.py:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(
# <ipython-input-12-c34e84fce376>:12: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(embed_model=embed_model)
# Generating embeddings:   0%|          | 0/248 [00:00<?, ?it/s]
# 100%|██████████| 496/496 [03:15<00:00,  2.54it/s]

# %%
val_results_ft_openai = [
    result for result in val_results_ft_openai if isinstance(result, dict)
]

df_openai_ft = pd.DataFrame(val_results_ft_openai)

hit_rate_openai_ft = df_openai_ft["is_hit"].mean()
mrr_openai_ft = df_openai_ft["reciprocal_rank"].mean()

print(f"Hit rate: {hit_rate_openai_ft}")
print(f"MRR: {mrr_openai_ft}")
# Out:
# Hit rate: 0.9637096774193549
# MRR: 0.8210685483870968

# %% [markdown]
# ## Open Source BAAI Model Evaluation

# %%
# Load the Base model without fine-tuning
base_embed_model = resolve_embed_model("local:BAAI/bge-small-en-v1.5")
bge_val_results = evaluate(VALIDATION_DATASET, base_embed_model)
# Out:
# <ipython-input-18-c34e84fce376>:12: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(embed_model=embed_model)
# Generating embeddings:   0%|          | 0/248 [00:00<?, ?it/s]
# 100%|██████████| 496/496 [00:53<00:00,  9.35it/s]

# %%
bge_val_results = [
    result for result in bge_val_results if isinstance(result, dict)
]

df_bge = pd.DataFrame(bge_val_results)

hit_rate_bge = df_bge["is_hit"].mean()
mrr_bge = df_bge["reciprocal_rank"].mean()

print(f"Hit rate: {hit_rate_bge}")
print(f"MRR: {mrr_bge}")
# Out:
# Hit rate: 0.8387096774193549
# MRR: 0.7207325268817205

# %% [markdown]
# ## FineTuned BAAI Adapter Embedding Model Evaluation

# %%
from llama_index.legacy.embeddings.adapter import LinearAdapterEmbeddingModel

# Load the Fine-tuned model.
embed_model = LinearAdapterEmbeddingModel(base_embed_model, "model_output_test")

val_results_finetuned = evaluate(VALIDATION_DATASET, embed_model)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /usr/local/lib/python3.10/dist-
# [nltk_data]     packages/llama_index/legacy/_static/nltk_cache...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /usr/local/lib/python3.10/dist-
# [nltk_data]     packages/llama_index/legacy/_static/nltk_cache...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /usr/local/lib/python3.10/dist-packages/llama_index/legacy/embeddings/adapter_utils.py:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(
# <ipython-input-18-c34e84fce376>:12: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(embed_model=embed_model)
# Generating embeddings:   0%|          | 0/248 [00:00<?, ?it/s]
# 100%|██████████| 496/496 [00:10<00:00, 47.26it/s]

# %%
val_results_finetuned = [
    result for result in val_results_finetuned if isinstance(result, dict)
]

df_finetuned = pd.DataFrame(val_results_finetuned)

hit_rate_finetuned = df_finetuned["is_hit"].mean()
mrr_finetuned = df_finetuned["reciprocal_rank"].mean()

print(f"Hit rate: {hit_rate_finetuned}")
print(f"MRR: {mrr_finetuned}")
# Out:
# Hit rate: 0.8629032258064516
# MRR: 0.7499663978494624
